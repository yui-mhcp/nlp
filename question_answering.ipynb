# %% [markdown]
# # Question Answering (Q&A) API
#
# This API allows to ask a general question to the model, get top-k results from your favorite search engine\* and let the model finds the answer !
#
# \* Currently Google, Bing and DuckDuckGo are supported but only the Google API is trully performant.

# %%
import json

from utils import to_json
from models.qa import answer_from_web

qa_pairs = [
    ('Where is malaga ?', 'https://en.wikipedia.org/wiki/M%C3%A1laga'),
    ('what is the rank of india in economic growth', 'https://en.wikipedia.org/wiki/Economy_of_India'),
    ('latest series of keeping up with the kardashians', 'https://en.wikipedia.org/wiki/List_of_Keeping_Up_with_the_Kardashians_episodes'),
    ('where is tchernobyl', 'https://en.wikipedia.org/wiki/Chernobyl_disaster'),
    ('what is multi layer perceptron', 'https://en.wikipedia.org/wiki/Multilayer_perceptron'),
    ('why the sky is blue', 'https://en.wikipedia.org/wiki/Sky')
]


for q, url in qa_pairs:
    pred = answer_from_web(q, save = False)[0]
    for k in ['paragraphs', 'titles', 'id']: pred.pop(k)
    print("Question : {} {}".format(q, json.dumps(to_json(pred), indent = 4)))
# Out:
# Try query Where is malaga ? on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Inputs shape : [(1, 7), (1,), (1, 16, 567), (1, 16)] - config : {'method': 'beam', 'max_input_texts': 16, 'input_select_mode': 'start', 'max_multi_input_length': 666, 'min_multi_input_length': 48, 'max_total_length': 13000, 'save': False}
# Question : Where is malaga ? {
#     "question": "Where is malaga ?",
#     "engine": "google",
#     "urls": [
#         "https://www.thevivalavita.com/where-is-malaga/",
#         "https://en.wikipedia.org/wiki/M%C3%A1laga",
#         "https://en.wikipedia.org/wiki/Province_of_M%C3%A1laga",
#         "https://en.wikipedia.org/wiki/History_of_M%C3%A1laga",
#         "https://en.wikipedia.org/wiki/M%C3%A1laga_CF"
#     ],
#     "config": {
#         "method": "beam",
#         "max_input_texts": 16,
#         "input_select_mode": "start",
#         "max_multi_input_length": 666,
#         "min_multi_input_length": 48,
#         "max_total_length": 13000,
#         "save": false,
#         "model": "m6_nq_coqa_newsqa_mag_off_entq_ct_wt_ib_2_2_dense"
#     },
#     "candidates": [
#         {
#             "text": "Spain</s>",
#             "score": -1.372718095779419
#         },
#         {
#             "text": "Southern Spain</s>",
#             "score": -1.526092529296875
#         },
#         {
#             "text": "in Southern Spain</s>",
#             "score": -2.490997552871704
#         },
#         {
#             "text": "southern Spain</s>",
#             "score": -2.7346606254577637
#         },
#         {
#             "text": "south of Spain</s>",
#             "score": -3.4243528842926025
#         }
#     ]
# }
# Try query what is the rank of india in economic growth on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Inputs shape : [(1, 12), (1,), (1, 16, 642), (1, 16)] - config : {'method': 'beam', 'max_input_texts': 16, 'input_select_mode': 'start', 'max_multi_input_length': 666, 'min_multi_input_length': 48, 'max_total_length': 13000, 'save': False}
# Question : what is the rank of india in economic growth {
#     "question": "what is the rank of india in economic growth",
#     "engine": "google",
#     "urls": [
#         "https://en.wikipedia.org/wiki/Economy_of_India",
#         "https://www.investopedia.com/insights/worlds-top-economies/",
#         "https://www.heritage.org/index/country/india",
#         "https://www.thehindu.com/news/national/india-overtakes-uk-to-become-fifth-largest-economy-in-the-world/article65844906.ece",
#         "https://www.weforum.org/agenda/2020/02/india-gdp-economy-growth-uk-france/"
#     ],
#     "config": {
#         "method": "beam",
#         "max_input_texts": 16,
#         "input_select_mode": "start",
#         "max_multi_input_length": 666,
#         "min_multi_input_length": 48,
#         "max_total_length": 13000,
#         "save": false,
#         "model": "m6_nq_coqa_newsqa_mag_off_entq_ct_wt_ib_2_2_dense"
#     },
#     "candidates": [
#         {
#             "text": "the top-most economy</s>",
#             "score": -1.3625438213348389
#         },
#         {
#             "text": "10th</s>",
#             "score": -2.0671021938323975
#         },
#         {
#             "text": "second</s>",
#             "score": -3.4140758514404297
#         },
#         {
#             "text": "the top-most economy, constituting 35 to 40% of the world GDP</s>",
#             "score": -3.5089831352233887
#         },
#         {
#             "text": "46th</s>",
#             "score": -3.669759750366211
#         }
#     ]
# }
# Try query latest series of keeping up with the kardashians on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Inputs shape : [(1, 13), (1,), (1, 16, 663), (1, 16)] - config : {'method': 'beam', 'max_input_texts': 16, 'input_select_mode': 'start', 'max_multi_input_length': 666, 'min_multi_input_length': 48, 'max_total_length': 13000, 'save': False}
# Question : latest series of keeping up with the kardashians {
#     "question": "latest series of keeping up with the kardashians",
#     "engine": "google",
#     "urls": [
#         "https://www.glamour.com/story/the-kardashians-season-2-trailer-details",
#         "https://www.digitalspy.com/tv/reality-tv/a40274662/the-kardashians-season-2-release-date-cast/",
#         "https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians",
#         "https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians#Production",
#         "https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians#Series_overview"
#     ],
#     "config": {
#         "method": "beam",
#         "max_input_texts": 16,
#         "input_select_mode": "start",
#         "max_multi_input_length": 666,
#         "min_multi_input_length": 48,
#         "max_total_length": 13000,
#         "save": false,
#         "model": "m6_nq_coqa_newsqa_mag_off_entq_ct_wt_ib_2_2_dense"
#     },
#     "candidates": [
#         {
#             "text": "The Kardashians</s>",
#             "score": -1.6147047281265259
#         },
#         {
#             "text": "Keeping Up With the Kardashians</s>",
#             "score": -2.8467273712158203
#         },
#         {
#             "text": "Did You Keep Up With the Kardashians</s>",
#             "score": -2.9413492679595947
#         },
#         {
#             "text": "Did You Keep Up With the Kardashians?</s>",
#             "score": -3.164806604385376
#         },
#         {
#             "text": "Doing With the Kardashians</s>",
#             "score": -3.3948068618774414
#         }
#     ]
# }
# Try query where is tchernobyl on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Inputs shape : [(1, 8), (1,), (1, 16, 620), (1, 16)] - config : {'method': 'beam', 'max_input_texts': 16, 'input_select_mode': 'start', 'max_multi_input_length': 666, 'min_multi_input_length': 48, 'max_total_length': 13000, 'save': False}
# Question : where is tchernobyl {
#     "question": "where is tchernobyl",
#     "engine": "google",
#     "urls": [
#         "https://en.wikipedia.org/wiki/Chernobyl_disaster",
#         "https://en.wikipedia.org/wiki/Chernobyl_Nuclear_Power_Plant",
#         "https://en.wikipedia.org/wiki/Pripyat",
#         "https://en.wikipedia.org/wiki/Effects_of_the_Chernobyl_disaster",
#         "https://en.wikipedia.org/wiki/Iodine_pit"
#     ],
#     "config": {
#         "method": "beam",
#         "max_input_texts": 16,
#         "input_select_mode": "start",
#         "max_multi_input_length": 666,
#         "min_multi_input_length": 48,
#         "max_total_length": 13000,
#         "save": false,
#         "model": "m6_nq_coqa_newsqa_mag_off_entq_ct_wt_ib_2_2_dense"
#     },
#     "candidates": [
#         {
#             "text": "Ukraine</s>",
#             "score": -1.1959463357925415
#         },
#         {
#             "text": "in the city of Chernobyl, Ukraine</s>",
#             "score": -2.338531255722046
#         },
#         {
#             "text": "Chernobyl</s>",
#             "score": -2.400235176086426
#         },
#         {
#             "text": "Russia</s>",
#             "score": -3.1970162391662598
#         },
#         {
#             "text": "Moscow</s>",
#             "score": -3.199899196624756
#         }
#     ]
# }
# Try query what is multi layer perceptron on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Inputs shape : [(1, 8), (1,), (1, 16, 537), (1, 16)] - config : {'method': 'beam', 'max_input_texts': 16, 'input_select_mode': 'start', 'max_multi_input_length': 666, 'min_multi_input_length': 48, 'max_total_length': 13000, 'save': False}
# Question : what is multi layer perceptron {
#     "question": "what is multi layer perceptron",
#     "engine": "google",
#     "urls": [
#         "https://en.wikipedia.org/wiki/Multilayer_perceptron",
#         "https://en.wikipedia.org/wiki/Multilayer_perceptron#Theory",
#         "https://en.wikipedia.org/wiki/Multilayer_perceptron#Activation_function",
#         "https://en.wikipedia.org/wiki/Multilayer_perceptron#Learning",
#         "https://en.wikipedia.org/wiki/Multilayer_perceptron#Terminology"
#     ],
#     "config": {
#         "method": "beam",
#         "max_input_texts": 16,
#         "input_select_mode": "start",
#         "max_multi_input_length": 666,
#         "min_multi_input_length": 48,
#         "max_total_length": 13000,
#         "save": false,
#         "model": "m6_nq_coqa_newsqa_mag_off_entq_ct_wt_ib_2_2_dense"
#     },
#     "candidates": [
#         {
#             "text": "a fully connected class of feedforward artificial neural network (ANN)</s>",
#             "score": -1.2140207290649414
#         },
#         {
#             "text": "a fully connected class of feedforward artificial neural network</s>",
#             "score": -1.8819613456726074
#         },
#         {
#             "text": "multilayer perceptron</s>",
#             "score": -2.5057475566864014
#         },
#         {
#             "text": "A multilayer perceptron</s>",
#             "score": -2.7478187084198
#         },
#         {
#             "text": "A multilayer perceptron (MLP) is a fully connected class of feedforward artificial neural network (ANN). The term MLP is used ambiguously, sometimes loosely to mean any feedforward ANN, sometimes strictly to refer to networks composed of multiple layers of perceptrons (with activation threshold); see \u00a7\u00a0Terminology. Multilayer perceptrons are sometimes colloquially referred to as \"vanilla\" neural networks, especially when they have a single hidden layer.</s>",
#             "score": -3.4245524406433105
#         }
#     ]
# }
# Try query why the sky is blue on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Inputs shape : [(1, 7), (1,), (1, 16, 418), (1, 16)] - config : {'method': 'beam', 'max_input_texts': 16, 'input_select_mode': 'start', 'max_multi_input_length': 666, 'min_multi_input_length': 48, 'max_total_length': 13000, 'save': False}
# Question : why the sky is blue {
#     "question": "why the sky is blue",
#     "engine": "google",
#     "urls": [
#         "https://www.rmg.co.uk/stories/topics/why-sky-blue",
#         "https://spaceplace.nasa.gov/blue-sky/en/",
#         "http://spaceplace.nasa.gov/blue-sky/en/",
#         "https://spaceplace.nasa.gov/tectonics-snap/en/",
#         "https://www.mcgill.ca/oss/articles-by-author/Ada%20McVean%20B.Sc."
#     ],
#     "config": {
#         "method": "beam",
#         "max_input_texts": 16,
#         "input_select_mode": "start",
#         "max_multi_input_length": 666,
#         "min_multi_input_length": 48,
#         "max_total_length": 13000,
#         "save": false,
#         "model": "m6_nq_coqa_newsqa_mag_off_entq_ct_wt_ib_2_2_dense"
#     },
#     "candidates": [
#         {
#             "text": "it reflects the blue of the seas and oceans</s>",
#             "score": -2.811279535293579
#         },
#         {
#             "text": "because small particles of dust, pollution, or other aerosols scatter light</s>",
#             "score": -3.0868873596191406
#         },
#         {
#             "text": "small particles of dust, pollution, or other aerosols scatter light</s>",
#             "score": -3.1583011150360107
#         },
#         {
#             "text": "small particles of dust, pollution, or other aerosols</s>",
#             "score": -3.2648301124572754
#         },
#         {
#             "text": "because it reflects the blue of the seas and oceans</s>",
#             "score": -3.6394288539886475
#         }
#     ]
# }

# %%
from models.qa import search_on_web

qa_pairs = [
    ('Where is malaga ?', 'https://en.wikipedia.org/wiki/M%C3%A1laga'),
    ('what is the rank of india in economic growth', 'https://en.wikipedia.org/wiki/Economy_of_India'),
    ('latest series of keeping up with the kardashians', 'https://en.wikipedia.org/wiki/List_of_Keeping_Up_with_the_Kardashians_episodes'),
    ('where is tchernobyl', 'https://en.wikipedia.org/wiki/Chernobyl_disaster'),
    ('what is multi layer perceptron', 'https://en.wikipedia.org/wiki/Multilayer_perceptron'),
    ('why the sky is blue', 'https://en.wikipedia.org/wiki/Sky')
]

for q, url in qa_pairs:
    urls = search_on_web(q, n = 5)['urls']
    print("Question : {}\nTop-5 most relevant websites :\n- {}".format(q, '\n- '.join(urls)))
# Out:
# Try query Where is malaga ? on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Question : Where is malaga ?
# Top-5 most relevant websites :
# - https://www.thevivalavita.com/where-is-malaga/
# - https://en.wikipedia.org/wiki/M%C3%A1laga
# - https://en.wikipedia.org/wiki/Province_of_M%C3%A1laga
# - https://en.wikipedia.org/wiki/History_of_M%C3%A1laga
# - https://en.wikipedia.org/wiki/M%C3%A1laga_CF
# Try query what is the rank of india in economic growth on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Question : what is the rank of india in economic growth
# Top-5 most relevant websites :
# - https://en.wikipedia.org/wiki/Economy_of_India
# - https://statisticstimes.com/economy/projected-world-gdp-ranking.php
# - https://www.investopedia.com/insights/worlds-top-economies/
# - https://timesofindia.indiatimes.com/business/india-business/india-best-performing-among-major-economies-in-the-world-report/articleshow/92765982.cms
# - https://timesofindia.indiatimes.com/business/india-business/india75-how-india-became-6th-largest-economy-in-world/articleshow/93567129.cms
# Try query latest series of keeping up with the kardashians on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Question : latest series of keeping up with the kardashians
# Top-5 most relevant websites :
# - https://www.glamour.com/story/the-kardashians-season-2-trailer-details
# - https://www.digitalspy.com/tv/reality-tv/a40274662/the-kardashians-season-2-release-date-cast/
# - https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians
# - https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians#Production
# - https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians#Series_overview
# Try query where is tchernobyl on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Question : where is tchernobyl
# Top-5 most relevant websites :
# - https://en.wikipedia.org/wiki/Chernobyl_disaster
# - https://en.wikipedia.org/wiki/Chernobyl_Nuclear_Power_Plant
# - https://en.wikipedia.org/wiki/Pripyat
# - https://en.wikipedia.org/wiki/Effects_of_the_Chernobyl_disaster
# - https://en.wikipedia.org/wiki/Iodine_pit
# Try query what is multi layer perceptron on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Question : what is multi layer perceptron
# Top-5 most relevant websites :
# - https://en.wikipedia.org/wiki/Multilayer_perceptron
# - https://en.wikipedia.org/wiki/Multilayer_perceptron#Theory
# - https://en.wikipedia.org/wiki/Multilayer_perceptron#Activation_function
# - https://en.wikipedia.org/wiki/Multilayer_perceptron#Learning
# - https://en.wikipedia.org/wiki/Multilayer_perceptron#Terminology
# Try query why the sky is blue on engine google...
# Cannot use async_timeout here : Timeout context manager should be used inside a task !
# Question : why the sky is blue
# Top-5 most relevant websites :
# - https://www.rmg.co.uk/stories/topics/why-sky-blue
# - https://spaceplace.nasa.gov/blue-sky/en/
# - http://spaceplace.nasa.gov/blue-sky/en/
# - https://spaceplace.nasa.gov/tectonics-snap/en/
# - https://spaceplace.nasa.gov/glossary/en/
